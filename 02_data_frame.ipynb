# %% [markdown]
# # Data Frame

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating Dataframe

# %%
data = np.random.randn(5,3)
pd.DataFrame(data)
# Out:
#           0         1         2
# 0  1.462155  1.357190  0.017147
# 1 -0.785337 -1.271933  0.434582
# 2 -1.099922  0.017425 -0.581532
# 3 -0.958274  1.341467  1.635699
# 4  0.239275 -0.050704  1.382751

# %%
# Giving Labels to column by list
names = ["age","workclass","fnlwgt","education","edu-num","marital-status","occupation","relationship","race","sex","cap-gain","cap-loss","hour/week","country","salary"]
df = pd.read_csv('adult.data.csv', 
                 header=None, # NO header applied
                 names=names) # Applying header

# %% [markdown]
# ## Attributes
# ```
# 1. df.head()
# 2. df.tail()
# 3. df.index
# 4. df.values
# 5. df.shape
# 6. df.size
# 7. df.columns
# 8. df.dtypes
# 9. df.info()
# 10. df.dtypes.value_counts()
# 11. df.describe()
# ```

# %%
# 1. df.head() > By default it shows first 5 data
df.head(3)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
#
#            occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White   Male      2174         0
# 1     Exec-managerial         Husband   White   Male         0         0
# 2   Handlers-cleaners   Not-in-family   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K
# 2         40   United-States   <=50K

# %%
# 2. df.tail() > By default it shows last 5 data
df.tail(3)
# Out:
#        age      workclass  fnlwgt education  edu-num       marital-status  \
# 32558   58        Private  151910   HS-grad        9              Widowed
# 32559   22        Private  201490   HS-grad        9        Never-married
# 32560   52   Self-emp-inc  287927   HS-grad        9   Married-civ-spouse
#
#              occupation relationship    race      sex  cap-gain  cap-loss  \
# 32558      Adm-clerical    Unmarried   White   Female         0         0
# 32559      Adm-clerical    Own-child   White     Male         0         0
# 32560   Exec-managerial         Wife   White   Female     15024         0
#
#        hour/week         country  salary
# 32558         40   United-States   <=50K
# 32559         20   United-States   <=50K
# 32560         40   United-States    >50K

# %%
# 3. df.index > shows total rows
df.index
# Out:
# RangeIndex(start=0, stop=32561, step=1)

# %%
# 4. df.values > shows values
df.values[:3]
# Out:
# array([[39, ' State-gov', 77516, ' Bachelors', 13, ' Never-married',
#         ' Adm-clerical', ' Not-in-family', ' White', ' Male', 2174, 0,
#         40, ' United-States', ' <=50K'],
#        [50, ' Self-emp-not-inc', 83311, ' Bachelors', 13,
#         ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White',
#         ' Male', 0, 0, 13, ' United-States', ' <=50K'],
#        [38, ' Private', 215646, ' HS-grad', 9, ' Divorced',
#         ' Handlers-cleaners', ' Not-in-family', ' White', ' Male', 0, 0,
#         40, ' United-States', ' <=50K']], dtype=object)

# %%
# 5. df.shape > Shows rowX column
df.shape
# Out:
# (32561, 15)

# %%
# 6. df.size > size of values
df.size
# Out:
# 488415

# %%
# 7. df.columns > list of columns
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'edu-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'cap-gain', 'cap-loss',
#        'hour/week', 'country', 'salary'],
#       dtype='object')

# %%
# 8. df.dtypes > shows data type of every column
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# edu-num            int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# cap-gain           int64
# cap-loss           int64
# hour/week          int64
# country           object
# salary            object
# dtype: object

# %%
# 9. df.info() > Shows info abot row, column, null values, data types & total memory 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# edu-num           32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# cap-gain          32561 non-null int64
# cap-loss          32561 non-null int64
# hour/week         32561 non-null int64
# country           32561 non-null object
# salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# 10. df.dtypes.value_counts() > total no. of datatype count for each coumn
df.dtypes.value_counts()
# Out:
# object    9
# int64     6
# dtype: int64

# %%
# 11. df.describe() > Statististical Calculations
df.describe()
# Out:
#                 age        fnlwgt       edu-num      cap-gain      cap-loss  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#           hour/week
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Select one or more column

# %%
# Selecting one column
print(df["education"].head())

# Selecting multiple columns
select = ['age','education','salary']
selected = df[select]
selected.head()
# Out:
# 0     Bachelors
# 1     Bachelors
# 2       HS-grad
# 3          11th
# 4     Bachelors
# Name: education, dtype: object
#    age   education  salary
# 0   39   Bachelors   <=50K
# 1   50   Bachelors   <=50K
# 2   38     HS-grad   <=50K
# 3   53        11th   <=50K
# 4   28   Bachelors   <=50K

# %% [markdown]
# ## Broad casting Operations

# %%
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
#
#          occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0      Adm-clerical   Not-in-family   White   Male      2174         0
# 1   Exec-managerial         Husband   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K

# %%
# every value of 'cap-gain' divided with 5.
df['cap-gain'] / 5

# multiplying every value of 'fnlwgt' with 'edu-num' df's
df['fnlwgt'] * df['edu-num']

# every single vlaue of df 'age' added with 5.
df['age'] + 5

# every single vlaue of df 'age' substracted with 5.
df['age'] = df['age'] - 5
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   34          State-gov   77516   Bachelors       13        Never-married
# 1   45   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
#
#          occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0      Adm-clerical   Not-in-family   White   Male      2174         0
# 1   Exec-managerial         Husband   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K

# %% [markdown]
# ## Drop Missing row or column

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0],
                   [3, 4, np.nan, 1],
                   [np.nan, np.nan, np.nan, 5],
                   [np.nan, np.nan, np.nan, np.nan]],
                   columns=list('ABCD'))
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  5.0
# 3  NaN  NaN NaN  NaN

# %%
# dropna = drop not a number
print(df.dropna(axis=0,    # axis = 0 > row wise
          how='any'), '\n') # any value in a row is nan > discard it

print(df.dropna(axis=0,    # axis = 0 > row wise
          how='all')) # every value in a row is nan > discard it
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []
#
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  5.0

# %%
df.dropna(axis=1,    # axis = 1 > column wise
          how='any') # any value in a row is nan > discard it
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df.dropna(axis=1,    # axis = 1 > column wise
          how='all') # every value in a row is nan > discard it
# Out:
#      A    B    D
# 0  NaN  2.0  0.0
# 1  3.0  4.0  1.0
# 2  NaN  NaN  5.0
# 3  NaN  NaN  NaN

# %%
df.drop(axis=0,        # axis = 0 > row wise
        labels=[2, 3]) # index
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0

# %%
df.drop(axis=1,             # axis = 1 > column wise 
        columns=['B', 'D']) # index
# Out:
#      A   C
# 0  NaN NaN
# 1  3.0 NaN
# 2  NaN NaN
# 3  NaN NaN

# %% [markdown]
# ## Filter Data

# %%
names = ["age","workclass","fnlwgt","education","edu-num","marital-status","occupation","relationship","race","sex","cap-gain","cap-loss","hour/week","country","salary"]
df = pd.read_csv('adult.data.csv', header=None, names=names)
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
#
#          occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0      Adm-clerical   Not-in-family   White   Male      2174         0
# 1   Exec-managerial         Husband   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K

# %%
# Filter conditioned data
print((df['age'] <= 50)[:3])

df[df['sex'] == ' Male'].head(2)
# Out:
# 0    True
# 1    True
# 2    True
# Name: age, dtype: bool
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
#
#          occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0      Adm-clerical   Not-in-family   White   Male      2174         0
# 1   Exec-managerial         Husband   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K

# %% [markdown]
# ## Multiple condition

# %%
# and "&" condition
# or "|" condition
con1 = df['sex'] == ' Male'
con2 = df['age'] >= 50

# and "&" Condition
print( (con1 & con2).head(2), '\n' )

# or "|" Condition
df[(con1 | con2)].head(2)
# Out:
# 0    False
# 1     True
# dtype: bool
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
#
#          occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0      Adm-clerical   Not-in-family   White   Male      2174         0
# 1   Exec-managerial         Husband   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K

# %%
# and, or condition
con3 = df['education'] == 'Masters'

df[(con1 & con2) | con3].head(3)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 7   52   Self-emp-not-inc  209642     HS-grad        9   Married-civ-spouse
#
#            occupation relationship    race    sex  cap-gain  cap-loss  \
# 1     Exec-managerial      Husband   White   Male         0         0
# 3   Handlers-cleaners      Husband   Black   Male         0         0
# 7     Exec-managerial      Husband   White   Male         0         0
#
#    hour/week         country  salary
# 1         13   United-States   <=50K
# 3         40   United-States   <=50K
# 7         45   United-States    >50K

# %% [markdown]
# ## obj.isin() & obj.between()

# %%
# obj.isin() > Multiple list of data contain in a dataframe
df[df['education'].isin([' 11th', ' 12th', ' Masters'])].head(2)
# Out:
#    age workclass  fnlwgt education  edu-num       marital-status  \
# 3   53   Private  234721      11th        7   Married-civ-spouse
# 5   37   Private  284582   Masters       14   Married-civ-spouse
#
#            occupation relationship    race      sex  cap-gain  cap-loss  \
# 3   Handlers-cleaners      Husband   Black     Male         0         0
# 5     Exec-managerial         Wife   White   Female         0         0
#
#    hour/week         country  salary
# 3         40   United-States   <=50K
# 5         40   United-States   <=50K

# %%
# obj.between() > Range b/t the given condition
df[df['age'].between(40, 42)].head(2)

# %% [markdown]
# ## nunique() & unique() method

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
# Total no. of unique elements in dataset of specific cloumn

## Method 1:
print(len(df['sex'].unique()))

## Method 2:
df['sex'].nunique()
# Out:
# 2
# 2

# %% [markdown]
# ## Sorting
# ### Sorting Values

# %%
names = ["age","workclass","fnlwgt","education","edu-num","marital-status","occupation","relationship","race","sex","cap-gain","cap-loss","hour/week","country","salary"]
df = pd.read_csv('adult.data.csv', header=None, names=names)
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
#
#          occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0      Adm-clerical   Not-in-family   White   Male      2174         0
# 1   Exec-managerial         Husband   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K

# %%
sort_descending = df.sort_values(by='country',  # choosen column 
               ascending=False,                 # descending order
               implace=True)                    # Permanant changes in org dataframe
sort_descending.head(2)
# Out:
#        age workclass  fnlwgt   education  edu-num       marital-status  \
# 12816   31   Private  182177   Bachelors       13   Married-civ-spouse
# 30543   22   Private  180060     HS-grad        9        Never-married
#
#              occupation    relationship    race    sex  cap-gain  cap-loss  \
# 12816     Other-service         Husband   White   Male         0         0
# 30543   Exec-managerial   Not-in-family   White   Male         0         0
#
#        hour/week      country  salary
# 12816         40   Yugoslavia   <=50K
# 30543         40   Yugoslavia   <=50K

# %%
sort_descending_multiple = df.sort_values(by=['country','age'],  # multiple columns
                                          ascending=False)       # Descending order
sort_descending_multiple.head(2)
# Out:
#        age workclass  fnlwgt    education  edu-num       marital-status  \
# 13125   66   Private  142624   Assoc-acdm       12   Married-civ-spouse
# 1025    56   Private  169133      HS-grad        9   Married-civ-spouse
#
#                occupation relationship    race    sex  cap-gain  cap-loss  \
# 13125   Machine-op-inspct      Husband   White   Male      5556         0
# 1025        Other-service      Husband   White   Male         0         0
#
#        hour/week      country  salary
# 13125         40   Yugoslavia    >50K
# 1025          50   Yugoslavia   <=50K

# %%
df.sort_values(by=['country','age'],            # Coutry ascending wise
               ascending=[False, True]).head(3) # age is descending wise
# Out:
#        age workclass  fnlwgt      education  edu-num  marital-status  \
# 6328    20   Private  175069   Some-college       10   Never-married
# 30543   22   Private  180060        HS-grad        9   Never-married
# 4447    25   Private  191230   Some-college       10   Never-married
#
#              occupation    relationship    race      sex  cap-gain  cap-loss  \
# 6328       Adm-clerical       Own-child   White     Male         0         0
# 30543   Exec-managerial   Not-in-family   White     Male         0         0
# 4447    Exec-managerial       Own-child   White   Female         0         0
#
#        hour/week      country  salary
# 6328          40   Yugoslavia   <=50K
# 30543         40   Yugoslavia   <=50K
# 4447          40   Yugoslavia   <=50K

# %% [markdown]
# ### sorting index

# %%
# sort by index 
df.sort_index(ascending=False).head(3)
# Out:
#        age      workclass  fnlwgt education  edu-num       marital-status  \
# 32560   52   Self-emp-inc  287927   HS-grad        9   Married-civ-spouse
# 32559   22        Private  201490   HS-grad        9        Never-married
# 32558   58        Private  151910   HS-grad        9              Widowed
#
#              occupation relationship    race      sex  cap-gain  cap-loss  \
# 32560   Exec-managerial         Wife   White   Female     15024         0
# 32559      Adm-clerical    Own-child   White     Male         0         0
# 32558      Adm-clerical    Unmarried   White   Female         0         0
#
#        hour/week         country  salary
# 32560         40   United-States    >50K
# 32559         20   United-States   <=50K
# 32558         40   United-States   <=50K

# %% [markdown]
# ## .loc() & .iloc() method

# %%
data= pd.read_csv('drinks.csv', index_col='country')
data.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# Andorra                              12.4        EU
# Angola                                5.9        AF

# %%
print(data.loc['Pakistan'])

data.loc[['Albania','India']]
# Out:
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       AS
# Name: Pakistan, dtype: object
#          beer_servings  spirit_servings  wine_servings  \
# country
# Albania             89              132             54
# India                9              114              0
#
#          total_litres_of_pure_alcohol continent
# country
# Albania                           4.9        EU
# India                             2.2        AS

# %%
data.loc['Algeria':'Australia']
# Out:
#                    beer_servings  spirit_servings  wine_servings  \
# country
# Algeria                       25                0             14
# Andorra                      245              138            312
# Angola                       217               57             45
# Antigua & Barbuda            102              128             45
# Argentina                    193               25            221
# Armenia                       21              179             11
# Australia                    261               72            212
#
#                    total_litres_of_pure_alcohol continent
# country
# Algeria                                     0.7        AF
# Andorra                                    12.4        EU
# Angola                                      5.9        AF
# Antigua & Barbuda                           4.9       NaN
# Argentina                                   8.3        SA
# Armenia                                     3.8        EU
# Australia                                  10.4        OC

# %%
data.loc['Algeria':'Australia']['beer_servings']
# Out:
# country
# Algeria               25
# Andorra              245
# Angola               217
# Antigua & Barbuda    102
# Argentina            193
# Armenia               21
# Australia            261
# Name: beer_servings, dtype: int64

# %%
print(data.iloc[0])   # Afghanistan
data.iloc[5: 10]
# Out:
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       AS
# Name: Afghanistan, dtype: object
#                    beer_servings  spirit_servings  wine_servings  \
# country
# Antigua & Barbuda            102              128             45
# Argentina                    193               25            221
# Armenia                       21              179             11
# Australia                    261               72            212
# Austria                      279               75            191
#
#                    total_litres_of_pure_alcohol continent
# country
# Antigua & Barbuda                           4.9       NaN
# Argentina                                   8.3        SA
# Armenia                                     3.8        EU
# Australia                                  10.4        OC
# Austria                                     9.7        EU

# %%
data.iloc[[3, 7, 12]]
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# Andorra            245              138            312
# Armenia             21              179             11
# Bahrain             42               63              7
#
#          total_litres_of_pure_alcohol continent
# country
# Andorra                          12.4        EU
# Armenia                           3.8        EU
# Bahrain                           2.0        AS

# %% [markdown]
# ## .astype() method : Data type conversion

# %%
names = ["age","workclass","fnlwgt","education","edu-num","marital-status","occupation","relationship","race","sex","cap-gain","cap-loss","hour/week","country","salary"]
df = pd.read_csv('adult.data.csv', header=None, names=names)
df.head(3)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
#
#            occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White   Male      2174         0
# 1     Exec-managerial         Husband   White   Male         0         0
# 2   Handlers-cleaners   Not-in-family   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K
# 2         40   United-States   <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# edu-num           32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# cap-gain          32561 non-null int64
# cap-loss          32561 non-null int64
# hour/week         32561 non-null int64
# country           32561 non-null object
# salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df['sex'] = df['sex'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# edu-num           32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null category
# cap-gain          32561 non-null int64
# cap-loss          32561 non-null int64
# hour/week         32561 non-null int64
# country           32561 non-null object
# salary            32561 non-null object
# dtypes: category(1), int64(6), object(8)
# memory usage: 3.5+ MB

# %% [markdown]
# ## set_index() : change index column

# %%
names = ["age","workclass","fnlwgt","education","edu-num","marital-status","occupation","relationship","race","sex","cap-gain","cap-loss","hour/week","country","salary"]
df = pd.read_csv('adult.data.csv', header=None, names=names, index_col='country')
df.head(1)
# Out:
#                 age   workclass  fnlwgt   education  edu-num  marital-status  \
# country
#  United-States   39   State-gov   77516   Bachelors       13   Never-married
#
#                    occupation    relationship    race    sex  cap-gain  \
# country
#  United-States   Adm-clerical   Not-in-family   White   Male      2174
#
#                 cap-loss  hour/week  salary
# country
#  United-States         0         40   <=50K

# %%
df.set_index('age').head(3)
# Out:
#              workclass  fnlwgt   education  edu-num       marital-status  \
# age
# 39           State-gov   77516   Bachelors       13        Never-married
# 50    Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 38             Private  215646     HS-grad        9             Divorced
#
#              occupation    relationship    race    sex  cap-gain  cap-loss  \
# age
# 39         Adm-clerical   Not-in-family   White   Male      2174         0
# 50      Exec-managerial         Husband   White   Male         0         0
# 38    Handlers-cleaners   Not-in-family   White   Male         0         0
#
#      hour/week  salary
# age
# 39          40   <=50K
# 50          13   <=50K
# 38          40   <=50K

# %%
df.set_index(['sex','salary']).head()
# Out:
#                 age          workclass  fnlwgt   education  edu-num  \
# sex     salary
#  Male    <=50K   39          State-gov   77516   Bachelors       13
#          <=50K   50   Self-emp-not-inc   83311   Bachelors       13
#          <=50K   38            Private  215646     HS-grad        9
#          <=50K   53            Private  234721        11th        7
#  Female  <=50K   28            Private  338409   Bachelors       13
#
#                      marital-status          occupation    relationship  \
# sex     salary
#  Male    <=50K        Never-married        Adm-clerical   Not-in-family
#          <=50K   Married-civ-spouse     Exec-managerial         Husband
#          <=50K             Divorced   Handlers-cleaners   Not-in-family
#          <=50K   Married-civ-spouse   Handlers-cleaners         Husband
#  Female  <=50K   Married-civ-spouse      Prof-specialty            Wife
#
#                   race  cap-gain  cap-loss  hour/week
# sex     salary
#  Male    <=50K   White      2174         0         40
#          <=50K   White         0         0         13
#          <=50K   White         0         0         40
#          <=50K   Black         0         0         40
#  Female  <=50K   Black         0         0         40

# %% [markdown]
# ## .apply() method on single column

# %%
names = ["age","workclass","fnlwgt","education","edu-num","marital-status","occupation","relationship","race","sex","cap-gain","cap-loss","hour/week","country","salary"]
df = pd.read_csv('adult.data.csv', header=None, names=names)
df.head(3)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
#
#            occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White   Male      2174         0
# 1     Exec-managerial         Husband   White   Male         0         0
# 2   Handlers-cleaners   Not-in-family   White   Male         0         0
#
#    hour/week         country  salary
# 0         40   United-States   <=50K
# 1         13   United-States   <=50K
# 2         40   United-States   <=50K

# %%
df['salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
def encodeSalary(salary):
    if salary == ' <=50K':
        return '1'
    else:
        return '2'

# %%
df['encoded_salary'] = df['salary'].apply(encodeSalary)

# %%
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
#
#          occupation    relationship    race    sex  cap-gain  cap-loss  \
# 0      Adm-clerical   Not-in-family   White   Male      2174         0
# 1   Exec-managerial         Husband   White   Male         0         0
#
#    hour/week         country  salary encoded_salary
# 0         40   United-States   <=50K              1
# 1         13   United-States   <=50K              1

# %%
def desc(row):
    age = row[0]
    sex = row[9]
    salary = row[14]
    temp= sex + ' earning ' + salary + '$'
    return temp

df['Description'] = df.apply(func=desc, axis='columns')

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  edu-num       marital-status  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 4   28            Private  338409   Bachelors       13   Married-civ-spouse
#
#            occupation    relationship    race      sex  cap-gain  cap-loss  \
# 0        Adm-clerical   Not-in-family   White     Male      2174         0
# 1     Exec-managerial         Husband   White     Male         0         0
# 2   Handlers-cleaners   Not-in-family   White     Male         0         0
# 3   Handlers-cleaners         Husband   Black     Male         0         0
# 4      Prof-specialty            Wife   Black   Female         0         0
#
#    hour/week         country  salary encoded_salary              Description
# 0         40   United-States   <=50K              1     Male earning  <=50K$
# 1         13   United-States   <=50K              1     Male earning  <=50K$
# 2         40   United-States   <=50K              1     Male earning  <=50K$
# 3         40   United-States   <=50K              1     Male earning  <=50K$
# 4         40            Cuba   <=50K              1   Female earning  <=50K$

# %%
# Random Sample
df.sample(n = 1)
# Out:
#        age workclass  fnlwgt      education  edu-num marital-status  \
# 18464   50   Private  271160   Some-college       10       Divorced
#
#       occupation    relationship    race      sex  cap-gain  cap-loss  \
# 18464      Sales   Not-in-family   White   Female         0         0
#
#        hour/week         country  salary encoded_salary
# 18464         40   United-States   <=50K              1
